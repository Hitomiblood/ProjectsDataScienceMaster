# %%
# %%capture
# !pip install --upgrade ultralytics

# %%
from ultralytics import YOLO

# %%
# %%capture
# !wget https://www.dropbox.com/scl/fi/maqbuw2e0s7ywa63dofun/bestSmall1920.pt?rlkey=n0pqsnjgycak6v7jx3qzhladt&st=04t3nonx&dl=0
# !mv bestSmall1920.pt?rlkey=n0pqsnjgycak6v7jx3qzhladt bestSmall1920.pt

# %%
# %%capture
# !wget https://www.dropbox.com/scl/fi/3mwyjefpr86kqktwrs1dh/HeadBest.pt?rlkey=b1h3rsr1z4cb82yh2najhvmrj&st=k4l2wefe&dl=0
# !mv HeadBest.pt?rlkey=b1h3rsr1z4cb82yh2najhvmrj HeadBest.pt

# %%
# Load a pretrained YOLO model (recommended for training)
model = YOLO('bestSmall1920.pt')

# %%
# Load a pretrained YOLO model (recommended for training)
modelHeads = YOLO('HeadBest.pt')

# %%
# %%capture
# Descargar el archivo ZIP desde la URL
# !wget https://www.dropbox.com/scl/fi/wgyl8ibb6rgo04ezuhzd5/Suppl_1.zip?rlkey=rmme7la6j6593wuacwiap8j46&st=qvcm3x1k&dl=0

# Crear la carpeta "Videos" si no existe
# !mkdir -p Videos

# !mv Suppl_1.zip?rlkey=rmme7la6j6593wuacwiap8j46 Suppl_1.zip

# Descomprimir el archivo ZIP en la carpeta "Videos"
# !unzip -o Suppl_1.zip -d Videos

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
from collections import defaultdict
import os

cv2.imshow = cv2_imshow

# %%
import os
import cv2
import numpy as np
from collections import defaultdict
from ultralytics import YOLO

# Directorio de entrada y salida
input_folder = "Videos/"
output_folder = "output_videos/"

# Crear el directorio de salida si no existe
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Listar los archivos de video en el directorio de entrada
video_files = [f for f in os.listdir(input_folder) if os.path.isfile(os.path.join(input_folder, f))]

# Iterar sobre cada archivo de video
for video_file in video_files:
    # Abrir el archivo de video de entrada
    video_path = os.path.join(input_folder, video_file)
    cap = cv2.VideoCapture(video_path)

    # Verificar si la apertura del video fue exitosa
    if not cap.isOpened():
        print(f"Error al abrir el archivo de video: {video_file}")
        continue

    # Obtener información del video de entrada
    fps = cap.get(cv2.CAP_PROP_FPS)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frame_size = (frame_width, frame_height)

    # Crear el objeto VideoWriter para el video de salida
    output_video_file = os.path.join(output_folder, f"{os.path.splitext(video_file)[0]}_Out.avi")
    fourcc = cv2.VideoWriter_fourcc(*'MJPG')  # Formato de compresión de vídeo
    out = cv2.VideoWriter(output_video_file, fourcc, fps, frame_size)

    # Store the track history
    track_history = defaultdict(lambda: [])
    head_track_history = defaultdict(lambda: [])
    last_head_position = defaultdict(lambda: None)

    model = YOLO('bestSmall1920.pt')

    # Diccionario para almacenar modelos de seguimiento de cabezas para cada espermatozoide
    head_trackers = defaultdict(lambda: YOLO('HeadBest.pt'))

    # Loop through the video frames
    while cap.isOpened():
        # Leer un cuadro del video
        success, frame = cap.read()

        if success:
            # Ejecutar el seguimiento YOLOv8 en el cuadro, persistiendo los tracks entre cuadros
            results = model.track(frame, persist=True)

            # Verificar si se detectaron resultados
            if results and len(results) > 0 and len(results[0].boxes) > 0:
                # Obtener las cajas y los IDs de seguimiento
                boxes = results[0].boxes.xywh.cpu().numpy()
                track_ids = results[0].boxes.id.cpu().numpy()

                # Dibujar las líneas de seguimiento
                for box, track_id in zip(boxes, track_ids):
                    x, y, w, h = box
                    track = track_history[track_id]
                    track.append((float(x), float(y)))  # x, y centro
                    if len(track) > 80:  # mantiene 80 tracks por 80 cuadros
                        track.pop(0)

                    # ************* Apartado a modificar *************
                    ################################################
                    # Recortar la región de interés (ROI) del cuadro original
                    roi = frame[int(y-h/2):int(y+h/2), int(x-w/2):int(x+w/2)]

                    # Inicializar variable para almacenar la nueva posición de la cabeza
                    new_head_position = None

                    # Verificar que el ROI no esté vacío
                    if roi.size != 0:
                        # Obtener el modelo de seguimiento de cabeza para este espermatozoide
                        head_tracker = head_trackers[track_id]

                        try:
                            # Ejecutar el modelo de detección de cabezas en el ROI
                            head_results = head_tracker.track(roi, persist=True, conf=0.1)

                            # Obtener las detecciones de cabezas
                            if head_results and len(head_results) > 0 and len(head_results[0].boxes) > 0:
                                head_boxes = head_results[0].boxes.xywh.cpu().numpy()
                                head_classes = head_results[0].boxes.cls.cpu().numpy()
                                for head_box, head_cls in zip(head_boxes, head_classes):
                                    if head_cls == 0:  # Si la clase es 0
                                        hx, hy, hw, hh = head_box
                                        head_center_x = x - w/2 + hx
                                        head_center_y = y - h/2 + hy

                                        new_head_position = (float(head_center_x), float(head_center_y))

                                        # Dibujar la caja de la cabeza en el cuadro original
                                        cv2.rectangle(frame,
                                                      (int(head_center_x - hw/2), int(head_center_y - hh/2)),
                                                      (int(head_center_x + hw/2), int(head_center_y + hh/2)),
                                                      (255, 0, 0), 2)
                        except Exception as e:
                            print(f"Error processing head tracking for track_id {track_id}: {e}")
                            # Usar la última posición conocida de la cabeza en caso de error
                            if last_head_position[track_id] is not None:
                                new_head_position = last_head_position[track_id]

                    # Si no se detectó una nueva cabeza, utilizar la última posición conocida
                    if new_head_position is None and last_head_position[track_id] is not None:
                        new_head_position = last_head_position[track_id]

                    # Actualizar la última posición conocida de la cabeza
                    if new_head_position is not None:
                        head_track = head_track_history[track_id]
                        head_track.append(new_head_position)
                        last_head_position[track_id] = new_head_position  # Actualizar la última posición conocida
                        if len(head_track) > 80:  # mantener 80 tracks por 80 cuadros
                            head_track.pop(0)
                    ################################################

                    # Dibujar las líneas de seguimiento
                    points = np.array(track, dtype=np.int32).reshape((-1, 1, 2))
                    cv2.polylines(frame, [points], isClosed=False, color=(0, 255, 255), thickness=3)

                    # Dibujar las líneas de seguimiento de las cabezas
                    head_points = np.array(head_track_history[track_id], dtype=np.int32).reshape((-1, 1, 2))
                    cv2.polylines(frame, [head_points], isClosed=False, color=(255, 0, 0), thickness=3)

                # Escribir el cuadro procesado en el archivo de salida
                out.write(frame)
            else:
                # Si no se detectaron resultados, escribir el cuadro original en el archivo de salida
                out.write(frame)

        else:
            # Terminar la ejecución si se alcanza el final del video
            break

    # Liberar los recursos
    cap.release()
    out.release()
# Out:
# 0: 1216x1920 27 Movils, 3932.2ms
# Speed: 51.9ms preprocess, 3932.2ms inference, 5.5ms postprocess per image at shape (1, 3, 1216, 1920)
#
# 0: 640x640 1 Head, 2 Tails, 2121.3ms
# Speed: 3.6ms preprocess, 2121.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 2 Tails, 1536.9ms
# Speed: 3.5ms preprocess, 1536.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1515.3ms
# Speed: 3.2ms preprocess, 1515.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1997.5ms
# Speed: 2.9ms preprocess, 1997.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1508.7ms
# Speed: 3.0ms preprocess, 1508.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 2543.8ms
# Speed: 3.6ms preprocess, 2543.8ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 3160.5ms
# Speed: 3.5ms preprocess, 3160.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1610.0ms
# Speed: 3.6ms preprocess, 1610.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 2 Tails, 1553.3ms
# Speed: 3.0ms preprocess, 1553.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 1 Head, 1497.8ms
# Speed: 2.8ms preprocess, 1497.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 2 Tails, 2261.9ms
# Speed: 3.6ms preprocess, 2261.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 2 Tails, 1605.1ms
# Speed: 4.4ms preprocess, 1605.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1553.4ms
# Speed: 3.0ms preprocess, 1553.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 2307.9ms
# Speed: 3.3ms preprocess, 2307.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1598.0ms
# Speed: 5.1ms preprocess, 1598.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Heads, 1 Tail, 1499.4ms
# Speed: 3.1ms preprocess, 1499.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 Heads, 1584.0ms
# Speed: 3.1ms preprocess, 1584.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Tail, 2340.4ms
# Speed: 3.4ms preprocess, 2340.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Tails, 1569.6ms
# Speed: 3.5ms preprocess, 1569.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1536.3ms
# Speed: 3.0ms preprocess, 1536.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Heads, 1 Tail, 2252.4ms
# Speed: 3.0ms preprocess, 2252.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Tails, 1822.4ms
# Speed: 3.3ms preprocess, 1822.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 1 Head, 2 Tails, 1535.3ms
# Speed: 3.4ms preprocess, 1535.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 3 Heads, 2 Tails, 1551.2ms
# Speed: 3.0ms preprocess, 1551.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Heads, 1 Tail, 2206.3ms
# Speed: 4.8ms preprocess, 2206.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 4 Tails, 1555.4ms
# Speed: 3.7ms preprocess, 1555.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 2 Heads, 1490.1ms
# Speed: 2.7ms preprocess, 1490.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 1216x1920 27 Movils, 4380.5ms
# Speed: 38.3ms preprocess, 4380.5ms inference, 2.2ms postprocess per image at shape (1, 3, 1216, 1920)
#
# 0: 640x640 1 Head, 2 Tails, 2092.6ms
# Speed: 9.4ms preprocess, 2092.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 2 Tails, 1504.1ms
# Speed: 4.4ms preprocess, 1504.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1521.0ms
# Speed: 3.7ms preprocess, 1521.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1504.5ms
# Speed: 3.5ms preprocess, 1504.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1508.3ms
# Speed: 3.5ms preprocess, 1508.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1524.7ms
# Speed: 7.7ms preprocess, 1524.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1539.3ms
# Speed: 3.5ms preprocess, 1539.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING: not enough matching points
# 0: 640x640 1 Head, 2357.3ms
# Speed: 3.5ms preprocess, 2357.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 2 Tails, 1989.2ms
# Speed: 3.5ms preprocess, 1989.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 10.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Tails, 1502.6ms
# Speed: 4.1ms preprocess, 1502.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 2 Tails, 1538.2ms
# Speed: 6.4ms preprocess, 1538.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING: not enough matching points
# 0: 640x640 1 Head, 1 Tail, 1530.7ms
# Speed: 4.0ms preprocess, 1530.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1496.9ms
# Speed: 3.8ms preprocess, 1496.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1507.7ms
# Speed: 6.6ms preprocess, 1507.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Heads, 1 Tail, 2451.9ms
# Speed: 7.2ms preprocess, 2451.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 5 Heads, 1961.8ms
# Speed: 4.0ms preprocess, 1961.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Tail, 1500.6ms
# Speed: 6.6ms preprocess, 1500.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Tails, 1522.9ms
# Speed: 6.5ms preprocess, 1522.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1498.3ms
# Speed: 3.5ms preprocess, 1498.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Heads, 1 Tail, 1542.2ms
# Speed: 4.2ms preprocess, 1542.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Tails, 1519.7ms
# Speed: 6.9ms preprocess, 1519.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 1 Head, 2 Tails, 1472.5ms
# Speed: 6.9ms preprocess, 1472.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 3 Heads, 2 Tails, 2384.7ms
# Speed: 3.7ms preprocess, 2384.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Heads, 1 Tail, 2100.9ms
# Speed: 4.8ms preprocess, 2100.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 4 Tails, 1542.9ms
# Speed: 5.3ms preprocess, 1542.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 2 Heads, 1484.6ms
# Speed: 3.6ms preprocess, 1484.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 1216x1920 27 Movils, 3604.3ms
# Speed: 29.8ms preprocess, 3604.3ms inference, 2.1ms postprocess per image at shape (1, 3, 1216, 1920)
#
# 0: 640x640 4 Heads, 1 Tail, 1507.8ms
# Speed: 4.0ms preprocess, 1507.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 2.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 3.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 1546.0ms
# Speed: 7.5ms preprocess, 1546.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1507.3ms
# Speed: 6.7ms preprocess, 1507.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 6.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Heads, 1498.0ms
# Speed: 6.5ms preprocess, 1498.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING: not enough matching points
# 0: 640x640 2 Heads, 2 Tails, 1534.5ms
# Speed: 6.4ms preprocess, 1534.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1512.5ms
# Speed: 7.3ms preprocess, 1512.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 1 Head, 1842.4ms
# Speed: 7.9ms preprocess, 1842.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 608)
#
# Error processing head tracking for track_id 11.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 12.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# WARNING: not enough matching points
# 0: 640x640 2 Heads, 1535.4ms
# Speed: 7.6ms preprocess, 1535.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 14.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 15.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Heads, 2 Tails, 1502.5ms
# Speed: 3.5ms preprocess, 1502.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 17.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 18.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 19.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 5 Heads, 1513.9ms
# Speed: 6.8ms preprocess, 1513.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 Heads, 1 Tail, 1541.6ms
# Speed: 3.4ms preprocess, 1541.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 22.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 23.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Heads, 2 Tails, 1493.2ms
# Speed: 3.5ms preprocess, 1493.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 25.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 1 Tail, 1972.3ms
# Speed: 5.3ms preprocess, 1972.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 1 Head, 1 Tail, 2320.6ms
# Speed: 4.4ms preprocess, 2320.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 1216x1920 27 Movils, 3583.0ms
# Speed: 19.4ms preprocess, 3583.0ms inference, 1.9ms postprocess per image at shape (1, 3, 1216, 1920)
#
# 0: 640x640 4 Heads, 1 Tail, 1530.4ms
# Speed: 4.9ms preprocess, 1530.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 2.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 3.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Heads, 2 Tails, 1480.6ms
# Speed: 4.8ms preprocess, 1480.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 2221.4ms
# Speed: 3.9ms preprocess, 2221.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 6.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Heads, 1482.6ms
# Speed: 5.5ms preprocess, 1482.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING: not enough matching points
# 0: 640x640 1 Head, 1 Tail, 1482.2ms
# Speed: 3.6ms preprocess, 1482.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1503.4ms
# Speed: 3.9ms preprocess, 1503.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 10.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 11.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Tails, 1481.0ms
# Speed: 5.1ms preprocess, 1481.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 13.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 14.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 15.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Heads, 2 Tails, 1487.4ms
# Speed: 4.5ms preprocess, 1487.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 17.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 18.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 1 Tail, 1532.8ms
# Speed: 3.4ms preprocess, 1532.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Heads, 1 Tail, 1501.7ms
# Speed: 3.5ms preprocess, 1501.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 Heads, 1 Tail, 1922.8ms
# Speed: 3.7ms preprocess, 1922.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 22.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 23.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Heads, 2 Tails, 1481.3ms
# Speed: 4.7ms preprocess, 1481.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 25.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 2406.4ms
# Speed: 5.9ms preprocess, 2406.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 1 Head, 1 Tail, 1682.1ms
# Speed: 3.4ms preprocess, 1682.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 1216x1920 27 Movils, 4877.1ms
# Speed: 14.5ms preprocess, 4877.1ms inference, 2.8ms postprocess per image at shape (1, 3, 1216, 1920)
#
# Error processing head tracking for track_id 1.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 2.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 1499.5ms
# Speed: 4.3ms preprocess, 1499.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1486.5ms
# Speed: 3.7ms preprocess, 1486.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1495.3ms
# Speed: 3.6ms preprocess, 1495.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 6.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 1996.0ms
# Speed: 3.4ms preprocess, 1996.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING: not enough matching points
# 0: 640x640 1 Head, 2 Tails, 2374.5ms
# Speed: 3.7ms preprocess, 2374.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Heads, 1 Tail, 1507.1ms
# Speed: 3.5ms preprocess, 1507.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 10.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 11.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Heads, 1500.1ms
# Speed: 4.0ms preprocess, 1500.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 13.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 14.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 15.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 16.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 17.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 18.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 19.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 20.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 1 Tail, 1508.0ms
# Speed: 4.3ms preprocess, 1508.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 22.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 23.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Heads, 1 Tail, 2430.7ms
# Speed: 3.4ms preprocess, 2430.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Heads, 6 Tails, 1746.3ms
# Speed: 3.6ms preprocess, 1746.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1512.6ms
# Speed: 3.9ms preprocess, 1512.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 27.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 1216x1920 27 Movils, 3527.3ms
# Speed: 15.8ms preprocess, 3527.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1216, 1920)
#
# 0: 640x640 2 Heads, 1 Tail, 1518.3ms
# Speed: 4.8ms preprocess, 1518.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 2.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 2320.7ms
# Speed: 4.0ms preprocess, 2320.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Tail, 1485.7ms
# Speed: 3.7ms preprocess, 1485.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Heads, 1 Tail, 1495.5ms
# Speed: 3.5ms preprocess, 1495.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1490.6ms
# Speed: 3.5ms preprocess, 1490.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Heads, 1498.4ms
# Speed: 3.5ms preprocess, 1498.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# WARNING: not enough matching points
# 0: 640x640 1 Head, 1489.0ms
# Speed: 3.4ms preprocess, 1489.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Heads, 1 Tail, 1492.1ms
# Speed: 3.5ms preprocess, 1492.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x608 2 Heads, 1763.7ms
# Speed: 3.2ms preprocess, 1763.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 608)
#
# Error processing head tracking for track_id 11.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 12.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 13.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Tails, 1476.7ms
# Speed: 6.8ms preprocess, 1476.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 15.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Heads, 2 Tails, 1480.3ms
# Speed: 6.0ms preprocess, 1480.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Heads, 1482.8ms
# Speed: 3.5ms preprocess, 1482.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 18.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 19.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 3 Heads, 1 Tail, 1733.6ms
# Speed: 3.3ms preprocess, 1733.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1488.5ms
# Speed: 4.0ms preprocess, 1488.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 22.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 23.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 1 Tail, 1485.1ms
# Speed: 4.8ms preprocess, 1485.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 2 Tails, 1493.6ms
# Speed: 3.5ms preprocess, 1493.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1539.7ms
# Speed: 3.8ms preprocess, 1539.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 27.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 1216x1920 27 Movils, 3866.8ms
# Speed: 17.6ms preprocess, 3866.8ms inference, 2.1ms postprocess per image at shape (1, 3, 1216, 1920)
#
# 0: 640x640 3 Heads, 1 Tail, 1493.9ms
# Speed: 4.9ms preprocess, 1493.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 2.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 1521.3ms
# Speed: 5.9ms preprocess, 1521.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1521.0ms
# Speed: 3.5ms preprocess, 1521.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1808.9ms
# Speed: 3.7ms preprocess, 1808.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 6.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 7.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 8.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 9.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x608 2 Heads, 1416.6ms
# Speed: 3.4ms preprocess, 1416.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# Error processing head tracking for track_id 11.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 12.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 13.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 14.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 15.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Heads, 2 Tails, 1490.9ms
# Speed: 5.9ms preprocess, 1490.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Heads, 1486.2ms
# Speed: 3.5ms preprocess, 1486.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 18.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 19.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Heads, 1544.6ms
# Speed: 4.4ms preprocess, 1544.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Heads, 2 Tails, 1510.1ms
# Speed: 7.9ms preprocess, 1510.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 22.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 23.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 1 Tail, 1501.2ms
# Speed: 5.5ms preprocess, 1501.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 2 Tails, 1498.8ms
# Speed: 3.8ms preprocess, 1498.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1525.8ms
# Speed: 3.6ms preprocess, 1525.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 27.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 1216x1920 27 Movils, 3816.3ms
# Speed: 15.1ms preprocess, 3816.3ms inference, 2.4ms postprocess per image at shape (1, 3, 1216, 1920)
#
# 0: 640x640 2 Heads, 1 Tail, 2460.2ms
# Speed: 3.4ms preprocess, 2460.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 2.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 3 Heads, 1 Tail, 1479.3ms
# Speed: 5.9ms preprocess, 1479.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1498.2ms
# Speed: 3.5ms preprocess, 1498.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1482.4ms
# Speed: 3.7ms preprocess, 1482.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 2 Tails, 1501.9ms
# Speed: 4.3ms preprocess, 1501.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 7.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# WARNING: not enough matching points
# 0: 640x640 1 Head, 1642.7ms
# Speed: 3.8ms preprocess, 1642.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 9.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 10.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 11.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 12.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Heads, 2 Tails, 1489.0ms
# Speed: 3.5ms preprocess, 1489.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 14.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 15.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 3 Tails, 1484.3ms
# Speed: 3.5ms preprocess, 1484.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 17.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 18.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 19.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 5 Heads, 1 Tail, 1482.3ms
# Speed: 5.6ms preprocess, 1482.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Heads, 3 Tails, 1495.0ms
# Speed: 3.5ms preprocess, 1495.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 22.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 23.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 1 Tail, 1473.2ms
# Speed: 3.5ms preprocess, 1473.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 2177.1ms
# Speed: 6.6ms preprocess, 2177.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 26.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 (no detections), 1569.0ms
# Speed: 3.8ms preprocess, 1569.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 1216x1920 27 Movils, 3549.9ms
# Speed: 16.6ms preprocess, 3549.9ms inference, 2.0ms postprocess per image at shape (1, 3, 1216, 1920)
#
# 0: 640x640 2 Heads, 1 Tail, 1502.8ms
# Speed: 5.2ms preprocess, 1502.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 2.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 3 Heads, 1 Tail, 1561.9ms
# Speed: 3.5ms preprocess, 1561.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 2419.5ms
# Speed: 3.5ms preprocess, 2419.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 1890.4ms
# Speed: 3.5ms preprocess, 1890.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Heads, 1 Tail, 1508.8ms
# Speed: 3.5ms preprocess, 1508.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 7.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# WARNING: not enough matching points
# 0: 640x640 1 Head, 1 Tail, 1497.6ms
# Speed: 3.5ms preprocess, 1497.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 9.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 10.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 11.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 12.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 1 Tail, 2050.2ms
# Speed: 3.3ms preprocess, 2050.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Tails, 1511.5ms
# Speed: 4.9ms preprocess, 1511.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 15.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 3 Tails, 1486.4ms
# Speed: 5.0ms preprocess, 1486.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Heads, 2 Tails, 1522.7ms
# Speed: 4.8ms preprocess, 1522.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 18.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 19.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 4 Heads, 1 Tail, 2197.6ms
# Speed: 5.0ms preprocess, 2197.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Heads, 3 Tails, 2165.3ms
# Speed: 3.5ms preprocess, 2165.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 22.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 23.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# WARNING: not enough matching points
# 0: 640x640 1 Head, 1 Tail, 1502.9ms
# Speed: 5.7ms preprocess, 1502.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1495.1ms
# Speed: 3.5ms preprocess, 1495.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 26.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 (no detections), 1467.9ms
# Speed: 4.7ms preprocess, 1467.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 1216x1920 27 Movils, 4836.6ms
# Speed: 16.4ms preprocess, 4836.6ms inference, 2.0ms postprocess per image at shape (1, 3, 1216, 1920)
#
# 0: 640x640 2 Heads, 2 Tails, 1493.6ms
# Speed: 4.9ms preprocess, 1493.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 2.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 3.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Tail, 1489.2ms
# Speed: 3.5ms preprocess, 1489.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 1 Tail, 1511.0ms
# Speed: 4.8ms preprocess, 1511.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 6.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 7.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 8.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 9.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 10.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 11.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 12.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 13.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 1 Tail, 1526.0ms
# Speed: 6.4ms preprocess, 1526.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 15.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 2194.7ms
# Speed: 3.7ms preprocess, 2194.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 17.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 18.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 19.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 1 Tail, 1511.8ms
# Speed: 4.1ms preprocess, 1511.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Heads, 2 Tails, 1541.9ms
# Speed: 3.5ms preprocess, 1541.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# ...
#
#
# Error processing head tracking for track_id 12.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 2 Tails, 1492.3ms
# Speed: 3.4ms preprocess, 1492.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 14.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 15.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 17.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 18.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 19.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 20.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 21.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 22.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 23.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 24.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 25.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 27.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Tails, 1924.4ms
# Speed: 3.4ms preprocess, 1924.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 28.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 16.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 1216x1920 28 Movils, 3496.3ms
# Speed: 15.5ms preprocess, 3496.3ms inference, 2.1ms postprocess per image at shape (1, 3, 1216, 1920)
#
# Error processing head tracking for track_id 1.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 2.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 3.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 2038.4ms
# Speed: 3.5ms preprocess, 2038.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Head, 2336.5ms
# Speed: 3.3ms preprocess, 2336.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 6.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 (no detections), 1541.0ms
# Speed: 3.9ms preprocess, 1541.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 8.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Tail, 1490.4ms
# Speed: 4.6ms preprocess, 1490.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x544 (no detections), 1255.5ms
# Speed: 3.0ms preprocess, 1255.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# Error processing head tracking for track_id 11.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 12.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 2 Tails, 2407.9ms
# Speed: 5.7ms preprocess, 2407.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 14.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 15.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 17.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 18.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 19.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 20.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 21.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 22.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 23.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 24.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 25.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 27.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 2 Tails, 1557.3ms
# Speed: 4.2ms preprocess, 1557.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 28.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 16.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 1216x1920 28 Movils, 4595.6ms
# Speed: 20.2ms preprocess, 4595.6ms inference, 1.6ms postprocess per image at shape (1, 3, 1216, 1920)
#
# Error processing head tracking for track_id 1.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 2.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 3.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 4.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 1 Head, 1498.1ms
# Speed: 4.7ms preprocess, 1498.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 6.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 (no detections), 2418.7ms
# Speed: 3.2ms preprocess, 2418.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 8.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 9.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x544 (no detections), 1278.4ms
# Speed: 3.0ms preprocess, 1278.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
#
# Error processing head tracking for track_id 11.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 12.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 (no detections), 1542.5ms
# Speed: 3.4ms preprocess, 1542.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 14.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 15.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 17.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 18.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 (no detections), 1489.3ms
# Speed: 4.1ms preprocess, 1489.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 20.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 21.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 22.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 23.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 24.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 25.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 27.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# 0: 640x640 3 Tails, 1489.5ms
# Speed: 3.2ms preprocess, 1489.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# Error processing head tracking for track_id 28.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
#
#
# Error processing head tracking for track_id 16.0: OpenCV(4.8.0) /io/opencv/modules/video/src/lkpyramid.cpp:1394: error: (-215:Assertion failed) prevPyr[level * lvlStep1].size() == nextPyr[level * lvlStep2].size() in function 'calc'
